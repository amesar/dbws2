# %%
import platform
print("Platform Version:",platform.python_version())

import sys
print("Sys Version:",sys.version.replace("\n"," - "))
# Out:
# <pre class="jp-command-status-text">Command execution completed</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
# Platform Version: 3.7.3
# Sys Version: 3.7.3 (default, Jan  8 2020, 19:43:49)  - [GCC 5.4.0 20160609]

# %%
import mlflow
print("MLflow Version:", mlflow.version.VERSION)
# Out:
# <pre class="jp-command-status-text">Command took 0.01 seconds -- by andre.mesarovic@databricks.com at 02/08/2020, 05:35:44 AM UTC on Jupyter</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
# MLflow Version: 1.6.0
